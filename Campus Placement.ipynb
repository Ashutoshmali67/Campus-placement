# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Campus placement - Sheet1 (3).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Sr. No.                                 215 non-null    int64
#  1   gender                                  215 non-null    object
#  2   Degree                                  215 non-null    object
#  3   Roll No.                                215 non-null    object
#  4   1st year percent                        215 non-null    float64
#  5   2nd year percent                        215 non-null    float64
#  6   3rd Year percent                        215 non-null    float64
#  7   4th Year Percent                        215 non-null    float64
#  8   Project marks                           215 non-null    float64
#  9   Total                                   215 non-null    float64
# ...

# %%
df.head()
# Out:
#    Sr. No. gender               Degree Roll No.  1st year percent  \
# 0        1      M  Biomedical Engineer       B1             67.00
# 1        2      M  Biomedical Engineer       B3             79.33
# 2        3      M  Electronic Engineer       E1             65.00
# 3        4      M  Biomedical Engineer       B4             56.00
# 4        5      M  Electronic Engineer       E2             85.80
#
#    2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 0             91.00             58.00              55.0          58.80
# 1             78.33             77.48              86.5          66.28
# 2             68.00             64.00              75.0          57.80
# 3             52.00             52.00              66.0          59.43
# 4             73.60             73.30              96.8          55.50
#
#     Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df.describe()
# Out:
#           Sr. No.  1st year percent  2nd year percent  3rd Year percent  \
# count  215.000000        215.000000        215.000000        215.000000
# mean   108.000000         67.303395         66.333163         66.370186
# std     62.209324         10.827205         10.897509          7.358743
# min      1.000000         40.890000         37.000000         50.000000
# 25%     54.500000         60.600000         60.900000         61.000000
# 50%    108.000000         67.000000         65.000000         66.000000
# 75%    161.500000         75.700000         73.000000         72.000000
# max    215.000000         89.400000         97.700000         91.000000
#
#        4th Year Percent  Project marks       Total  \
# count        215.000000     215.000000  215.000000
# mean          72.100558      62.278186   66.857609
# std           13.275956       5.833385    6.698428
# min           50.000000      51.210000   52.020000
# 25%           60.000000      57.945000   62.260000
# ...

# %% [markdown]
# # Which Roll No. Has highest Total ?

# %%
df.nlargest(1,'Total')
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 24       25      M  Biomedical Engineer      B12              76.5
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 24              97.7             78.86              97.4          74.01
#
#     Total Work Experience             specialisation ON Campus Placement  \
# 24   84.6              No  Electronic Product Design              Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 24                               360000.0                  NaN
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 24                                     NaN                          Delhi

# %% [markdown]
# # Which Roll No. Has Lowest Total ?

# %%
df.nsmallest(1,'Total')
# Out:
#     Sr. No. gender                    Degree Roll No.  1st year percent  \
# 49       50      F  Instrumentation Engineer     IE14              50.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 49              37.0              52.0              65.0          56.11
#
#     Total Work Experience specialisation ON Campus Placement  \
# 49  52.02              No    Embedded C           Not Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 49                                    NaN               Placed
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 49                                287000.0                         Indore

# %% [markdown]
# # How Many student score less Than 60

# %%
df[(df['Total']<60)].head()
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 3         4      M  Biomedical Engineer       B4              56.0
# 5         6      M  Biomedical Engineer       B5              55.0
# 9        10      M  Electronic Engineer       E6              58.0
# 12       13      F  Electronic Engineer       E9              47.0
# 14       15      M  Electronic Engineer      E11              62.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 3               52.0             52.00              66.0          59.43
# 5               49.8             67.25              55.0          51.58
# 9               70.0             61.00              54.0          52.21
# 12              55.0             65.00              62.0          65.04
# 14              47.0             50.00              76.0          54.96
#
#     Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df[(df['Total']<60)].count()
# Out:
# Sr. No.                                   35
# gender                                    35
# Degree                                    35
# Roll No.                                  35
# 1st year percent                          35
# 2nd year percent                          35
# 3rd Year percent                          35
# 4th Year Percent                          35
# Project marks                             35
# Total                                     35
# Work Experience                           35
# specialisation                            35
# ON Campus Placement                       35
# Salary of ON campus Placement Student     10
# OFF Campus Placement                      25
# Salary of OFF Campus Placement Student    24
# Job Location of Placed student            34
# dtype: int64

# %% [markdown]
# # How Many student Score greter than 80

# %%
df[(df['Total']>80)]
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 21        22      F  Electronic Engineer      E24             79.00
# 24        25      M  Biomedical Engineer      B12             76.50
# 85        86      F  Electronic Engineer      E85             83.84
# 90        91      F  Electronic Engineer      E88             85.00
# 107      108      M  Electronic Engineer     E101             82.00
# 118      119      M  Biomedical Engineer      B49             76.00
# 134      135      F  Electronic Engineer     E123             77.44
# 177      178      F  Electronic Engineer     E170             73.00
# 210      211      M  Electronic Engineer     E214             80.60
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 21              76.00             85.00             95.00          69.06
# 24              97.70             78.86             97.40          74.01
# ...

# %%
df[(df['Total']>80)].count()
# Out:
# Sr. No.                                   9
# gender                                    9
# Degree                                    9
# Roll No.                                  9
# 1st year percent                          9
# 2nd year percent                          9
# 3rd Year percent                          9
# 4th Year Percent                          9
# Project marks                             9
# Total                                     9
# Work Experience                           9
# specialisation                            9
# ON Campus Placement                       9
# Salary of ON campus Placement Student     8
# OFF Campus Placement                      1
# Salary of OFF Campus Placement Student    1
# Job Location of Placed student            9
# dtype: int64

# %% [markdown]
# # which  students get high salary package from on campus placement

# %%
df[(df['Salary of ON campus Placement Student']>500000)]
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 119      120      M  Electronic Engineer     E110              60.8
# 150      151      M  Biomedical Engineer      B58              71.0
# 177      178      F  Electronic Engineer     E170              73.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 119             68.40              64.6             82.66          64.34
# 150             58.66              58.0             56.00          61.30
# 177             97.00              79.0             89.00          70.81
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 119  68.14             Yes  Electronic Product Design              Placed
# 150  60.99             Yes  Electronic Product Design              Placed
# 177  81.76             Yes  Electronic Product Design              Placed
#
#      Salary of ON campus Placement Student OFF Campus Placement  \
# ...

# %%
df[(df['Salary of ON campus Placement Student']>500000)].nlargest(1,'Salary of ON campus Placement Student')
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 119      120      M  Electronic Engineer     E110              60.8
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 119              68.4              64.6             82.66          64.34
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 119  68.14             Yes  Electronic Product Design              Placed
#
#      Salary of ON campus Placement Student OFF Campus Placement  \
# 119                               940000.0                  NaN
#
#      Salary of OFF Campus Placement Student Job Location of Placed student
# 119                                     NaN                         Mumbai

# %% [markdown]
# # Which student have low Salary Package from On-Campus Placement

# %%
df.nsmallest(1,'Salary of ON campus Placement Student')
# Out:
#    Sr. No. gender               Degree Roll No.  1st year percent  \
# 1        2      M  Biomedical Engineer       B3             79.33
#
#    2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 1             78.33             77.48              86.5          66.28
#
#     Total Work Experience             specialisation ON Campus Placement  \
# 1  77.584             Yes  Electronic Product Design              Placed
#
#    Salary of ON campus Placement Student OFF Campus Placement  \
# 1                               200000.0                  NaN
#
#    Salary of OFF Campus Placement Student Job Location of Placed student
# 1                                     NaN                         Mumbai

# %% [markdown]
# # which student has average score and have Good salary Package

# %%
df[(df['Salary of ON campus Placement Student']>200000) & (df['Total']<60)]
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 12        13      F  Electronic Engineer       E9             47.00
# 14        15      M  Electronic Engineer      E11             62.00
# 20        21      M  Electronic Engineer      E22             62.00
# 25        26      F  Electronic Engineer      E27             52.58
# 94        95      M  Electronic Engineer      E92             58.00
# 112      113      M  Electronic Engineer     E105             58.00
# 154      155      M  Electronic Engineer     E141             53.00
# 166      167      M  Electronic Engineer     E156             62.00
# 176      177      F  Electronic Engineer     E168             59.00
# 203      204      M  Electronic Engineer     E207             55.68
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 12              55.00             65.00             62.00          65.04
# ...

# %%
df[(df['Salary of ON campus Placement Student']>200000) & (df['Total']<60)].count()
# Out:
# Sr. No.                                   10
# gender                                    10
# Degree                                    10
# Roll No.                                  10
# 1st year percent                          10
# 2nd year percent                          10
# 3rd Year percent                          10
# 4th Year Percent                          10
# Project marks                             10
# Total                                     10
# Work Experience                           10
# specialisation                            10
# ON Campus Placement                       10
# Salary of ON campus Placement Student     10
# OFF Campus Placement                       0
# Salary of OFF Campus Placement Student     0
# Job Location of Placed student            10
# dtype: int64

# %%
df[(df['Salary of ON campus Placement Student']>200000) & (df['Total']<60)].nlargest(1,'Salary of ON campus Placement Student')
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 14       15      M  Electronic Engineer      E11              62.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 14              47.0              50.0              76.0          54.96
#
#     Total Work Experience specialisation ON Campus Placement  \
# 14  57.99             Yes    Embedded C               Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 14                               411000.0                  NaN
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 14                                     NaN                         Mumbai

# %% [markdown]
# # How many students having Total grater than 70 having work experience but  not get selected in ON Campus Placement

# %%
df[(df['ON Campus Placement']=='Not Placed')& (df['Work Experience']=='Yes')& (df['Total']>70)]
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 97        98      F  Electronic Engineer      E95              70.5
# 165      166      F  Electronic Engineer     E154              63.3
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 97              62.50              61.0             93.91          69.03
# 165             78.33              74.0             80.00          74.56
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 97   71.38             Yes  Electronic Product Design          Not Placed
# 165  74.03             Yes  Electronic Product Design          Not Placed
#
#      Salary of ON campus Placement Student OFF Campus Placement  \
# 97                                     NaN           Not Placed
# 165                                    NaN               Placed
#
#      Salary of OFF Campus Placement Student Job Location of Placed student
# ...

# %% [markdown]
# # How Many student are not selected in ON campus placement

# %%
df[(df['ON Campus Placement']=='Not Placed')]
# Out:
#      Sr. No. gender                    Degree Roll No.  1st year percent  \
# 3          4      M       Biomedical Engineer       B4              56.0
# 5          6      M       Biomedical Engineer       B5              55.0
# 6          7      F       Electronic Engineer       E3              46.0
# 9         10      M       Electronic Engineer       E6              58.0
# 17        18      F       Electronic Engineer      E14              55.0
# ..       ...    ...                       ...      ...               ...
# 198      199      F  Instrumentation Engineer     IE35              67.0
# 201      202      M       Electronic Engineer     E204              54.2
# 206      207      M       Electronic Engineer     E210              41.0
# 208      209      F       Electronic Engineer     E212              43.0
# 214      215      M       Electronic Engineer     E224              62.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# ...

# %% [markdown]
# # The digramatic representation of ON Campus Placement record

# %%
plt.figure(figsize=(7,7))
df["Degree"].value_counts().plot.pie(autopct="%1.2f%%")
plt.title("Degree")
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(16,10))
sns.countplot(data=df,x='Degree',hue='ON Campus Placement',ax=axes[0,0])
sns.countplot(data=df,x='gender',hue='ON Campus Placement',ax=axes[0,1])
sns.countplot(data=df,x='specialisation',hue='ON Campus Placement',ax=axes[1,0])
sns.countplot(data=df,x='ON Campus Placement',ax=axes[1,1])
plt.show()

# %%
df.groupby('specialisation')['ON Campus Placement'].value_counts()
# Out:
# specialisation             ON Campus Placement
# Electronic Product Design  Placed                 94
#                            Not Placed             26
# Embedded C                 Placed                 55
#                            Not Placed             40
# Name: ON Campus Placement, dtype: int64

# %%
plt.figure(figsize=(11,11))
df.groupby('specialisation')['ON Campus Placement'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='ON Campus Placement'>

# %%
df.groupby("Degree")["ON Campus Placement"].value_counts()
# Out:
# Degree                    ON Campus Placement
# Biomedical Engineer       Placed                  40
#                           Not Placed              19
# Electronic Engineer       Placed                 104
#                           Not Placed              41
# Instrumentation Engineer  Not Placed               6
#                           Placed                   5
# Name: ON Campus Placement, dtype: int64

# %%
plt.figure(figsize=(11,11))
df.groupby("Degree")["ON Campus Placement"].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='ON Campus Placement'>

# %%
plt.figure(figsize=(11,11))
df.groupby("Degree")["ON Campus Placement"].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Degree,ON Campus Placement'>

# %%
df.groupby('Job Location of Placed student')['ON Campus Placement'].value_counts()
# Out:
# Job Location of Placed student  ON Campus Placement
# Banglore                        Not Placed              11
#                                 Placed                   2
# Bhopal                          Not Placed              11
#                                 Placed                   3
# Delhi                           Not Placed              12
#                                 Placed                   5
# Hydrabad                        Not Placed               6
#                                 Placed                   1
# Indore                          Not Placed              14
#                                 Placed                   4
# Mumbai                          Placed                 132
# Pune                            Not Placed               9
#                                 Placed                   2
# Name: ON Campus Placement, dtype: int64

# %%
plt.figure(figsize=(11,11))
df.groupby('Job Location of Placed student')['ON Campus Placement'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Job Location of Placed student,ON Campus Placement'>

# %% [markdown]
# #### so total 66 students did not placed in ON Campus Placement

# %% [markdown]
# # So,The Student did not placed in ON-Campus Placement,are tried to OFF-Campus Placement

# %%
df[(df['ON Campus Placement']=='Not Placed')]
# Out:
#      Sr. No. gender                    Degree Roll No.  1st year percent  \
# 3          4      M       Biomedical Engineer       B4              56.0
# 5          6      M       Biomedical Engineer       B5              55.0
# 6          7      F       Electronic Engineer       E3              46.0
# 9         10      M       Electronic Engineer       E6              58.0
# 17        18      F       Electronic Engineer      E14              55.0
# ..       ...    ...                       ...      ...               ...
# 198      199      F  Instrumentation Engineer     IE35              67.0
# 201      202      M       Electronic Engineer     E204              54.2
# 206      207      M       Electronic Engineer     E210              41.0
# 208      209      F       Electronic Engineer     E212              43.0
# 214      215      M       Electronic Engineer     E224              62.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# ...

# %% [markdown]
# # Students who are Place in Off-Campus Placement

# %%
df[(df['OFF Campus Placement']=='Placed')].head()
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 3         4      M  Biomedical Engineer       B4              56.0
# 5         6      M  Biomedical Engineer       B5              55.0
# 6         7      F  Electronic Engineer       E3              46.0
# 9        10      M  Electronic Engineer       E6              58.0
# 17       18      F  Electronic Engineer      E14              55.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 3               52.0             52.00             66.00          59.43
# 5               49.8             67.25             55.00          51.58
# 6               49.2             79.00             74.28          53.29
# 9               70.0             61.00             54.00          52.21
# 17              67.0             64.00             60.00          67.28
#
#     Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df[(df['OFF Campus Placement']=='Placed')].count()
# Out:
# Sr. No.                                   63
# gender                                    63
# Degree                                    63
# Roll No.                                  63
# 1st year percent                          63
# 2nd year percent                          63
# 3rd Year percent                          63
# 4th Year Percent                          63
# Project marks                             63
# Total                                     63
# Work Experience                           63
# specialisation                            63
# ON Campus Placement                       63
# Salary of ON campus Placement Student      0
# OFF Campus Placement                      63
# Salary of OFF Campus Placement Student    63
# Job Location of Placed student            63
# dtype: int64

# %% [markdown]
# # student who Total Greter than 80 and placed

# %%
df[(df['Total']>80)&(df['OFF Campus Placement']=='Placed')]
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 21       22      F  Electronic Engineer      E24              79.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 21              76.0              85.0              95.0          69.06
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 21  80.812              No  Electronic Product Design          Not Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 21                                    NaN               Placed
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 21                                318500.0                         Indore

# %% [markdown]
# # student who score Average total and placed in off campus placement

# %%
df[(df['Total']<60)&(df['OFF Campus Placement']=='Placed')].head()
# Out:
#     Sr. No. gender                    Degree Roll No.  1st year percent  \
# 3         4      M       Biomedical Engineer       B4              56.0
# 5         6      M       Biomedical Engineer       B5              55.0
# 9        10      M       Electronic Engineer       E6              58.0
# 34       35      M  Instrumentation Engineer     IE10              62.0
# 42       43      M  Instrumentation Engineer     IE12              49.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 3               52.0             52.00             66.00          59.43
# 5               49.8             67.25             55.00          51.58
# 9               70.0             61.00             54.00          52.21
# 34              51.0             52.00             68.44          62.77
# 42              39.0             65.00             63.00          51.21
#
#     Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df[(df['Total']<60)&(df['OFF Campus Placement']=='Placed')].count()
# Out:
# Sr. No.                                   24
# gender                                    24
# Degree                                    24
# Roll No.                                  24
# 1st year percent                          24
# 2nd year percent                          24
# 3rd Year percent                          24
# 4th Year Percent                          24
# Project marks                             24
# Total                                     24
# Work Experience                           24
# specialisation                            24
# ON Campus Placement                       24
# Salary of ON campus Placement Student      0
# OFF Campus Placement                      24
# Salary of OFF Campus Placement Student    24
# Job Location of Placed student            24
# dtype: int64

# %% [markdown]
# # Student get highest salary package from off-camus placement

# %%
df[(df['Total']<60)&(df['OFF Campus Placement']=='Placed')].nlargest(1,'Salary of OFF Campus Placement Student')
# Out:
#     Sr. No. gender                    Degree Roll No.  1st year percent  \
# 34       35      M  Instrumentation Engineer     IE10              62.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 34              51.0              52.0             68.44          62.77
#
#     Total Work Experience specialisation ON Campus Placement  \
# 34  59.24             Yes    Embedded C           Not Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 34                                    NaN               Placed
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 34                                550000.0                          Delhi

# %%
df[(df['Total']<60)&(df['OFF Campus Placement']=='Placed')].nsmallest(1,'Salary of OFF Campus Placement Student')
# Out:
#    Sr. No. gender               Degree Roll No.  1st year percent  \
# 3        4      M  Biomedical Engineer       B4              56.0
#
#    2nd year percent  3rd Year percent  4th Year Percent  Project marks  Total  \
# 3              52.0              52.0              66.0          59.43  57.08
#
#   Work Experience specialisation ON Campus Placement  \
# 3             Yes    Embedded C           Not Placed
#
#    Salary of ON campus Placement Student OFF Campus Placement  \
# 3                                    NaN               Placed
#
#    Salary of OFF Campus Placement Student Job Location of Placed student
# 3                                200000.0                          Delhi

# %% [markdown]
# # student score between 60 and 80 and get Placed

# %%
df[(df['Total']<80)&(df['Total']>60)&(df['OFF Campus Placement']=='Placed')].head()
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 6         7      F  Electronic Engineer       E3              46.0
# 17       18      F  Electronic Engineer      E14              55.0
# 18       19      F  Electronic Engineer      E20              63.0
# 29       30      M  Electronic Engineer      E31              62.0
# 31       32      F  Biomedical Engineer      B14              67.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 6               49.2              79.0             74.28          53.29
# 17              67.0              64.0             60.00          67.28
# 18              66.0              64.0             68.00          64.08
# 29              67.0              58.0             77.00          51.29
# 31              53.0              65.0             64.00          58.32
#
#      Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df[(df['Total']<80)&(df['Total']>60)&(df['OFF Campus Placement']=='Placed')].nlargest(1,'Salary of OFF Campus Placement Student')
# Out:
#      Sr. No. gender               Degree Roll No.  1st year percent  \
# 190      191      F  Electronic Engineer     E186              64.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 190              70.2              61.0              50.0           62.5
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 190  61.54              No  Electronic Product Design          Not Placed
#
#      Salary of ON campus Placement Student OFF Campus Placement  \
# 190                                    NaN               Placed
#
#      Salary of OFF Campus Placement Student Job Location of Placed student
# 190                                543000.0                          Delhi

# %% [markdown]
# # Student get lowest Salary package from off-campus Placement

# %%
df[(df['Total']<80)&(df['Total']>60)&(df['OFF Campus Placement']=='Placed')].nsmallest(1,'Salary of OFF Campus Placement Student')
# Out:
#     Sr. No. gender               Degree Roll No.  1st year percent  \
# 75       76      F  Electronic Engineer      E78              59.0
#
#     2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 75              62.0              77.5              74.0           67.0
#
#     Total Work Experience specialisation ON Campus Placement  \
# 75   67.9              No    Embedded C           Not Placed
#
#     Salary of ON campus Placement Student OFF Campus Placement  \
# 75                                    NaN               Placed
#
#     Salary of OFF Campus Placement Student Job Location of Placed student
# 75                                185000.0                           Pune

# %% [markdown]
# # Those Students Nither placed in ON Campus Placement Nor in OFF campus Placement

# %%
df[(df['Total']>50)&(df['OFF Campus Placement']=='Not Placed')]
# Out:
#      Sr. No. gender                    Degree Roll No.  1st year percent  \
# 36        37      M       Electronic Engineer      E40              51.0
# 97        98      F       Electronic Engineer      E95              70.5
# 198      199      F  Instrumentation Engineer     IE35              67.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 36               44.0              57.0             64.00          51.45
# 97               62.5              61.0             93.91          69.03
# 198              70.0              65.0             88.00          71.96
#
#      Total Work Experience             specialisation ON Campus Placement  \
# 36   53.49              No  Electronic Product Design          Not Placed
# 97   71.38             Yes  Electronic Product Design          Not Placed
# 198  72.39              No                Embedded C           Not Placed
#
#      Salary of ON campus Placement Student OFF Campus Placement  \
# ...

# %% [markdown]
# # student get higher salary package in OFF campus Placement

# %%
df[(df['Salary of OFF Campus Placement Student']>500000)&(df['OFF Campus Placement']=='Placed')]
# Out:
#      Sr. No. gender                    Degree Roll No.  1st year percent  \
# 34        35      M  Instrumentation Engineer     IE10              62.0
# 105      106      M       Biomedical Engineer      B43              59.0
# 136      137      F       Electronic Engineer     E125              47.0
# 168      169      F       Electronic Engineer     E160              48.0
# 190      191      F       Electronic Engineer     E186              64.0
#
#      2nd year percent  3rd Year percent  4th Year Percent  Project marks  \
# 34               51.0              52.0             68.44          62.77
# 105              64.0              58.0             85.00          55.30
# 136              59.0              64.0             78.00          61.58
# 168              51.0              58.0             60.00          58.79
# 190              70.2              61.0             50.00          62.50
#
#      Total Work Experience             specialisation ON Campus Placement  \
# ...

# %%
df[(df['Salary of OFF Campus Placement Student']>500000)&(df['OFF Campus Placement']=='Placed')].count()
# Out:
# Sr. No.                                   5
# gender                                    5
# Degree                                    5
# Roll No.                                  5
# 1st year percent                          5
# 2nd year percent                          5
# 3rd Year percent                          5
# 4th Year Percent                          5
# Project marks                             5
# Total                                     5
# Work Experience                           5
# specialisation                            5
# ON Campus Placement                       5
# Salary of ON campus Placement Student     0
# OFF Campus Placement                      5
# Salary of OFF Campus Placement Student    5
# Job Location of Placed student            5
# dtype: int64

# %% [markdown]
# # Diagramatic Representation of OFF-Campus Placement

# %%
df.groupby('Job Location of Placed student')['OFF Campus Placement'].value_counts()
# Out:
# Job Location of Placed student  OFF Campus Placement
# Banglore                        Placed                  11
# Bhopal                          Placed                  11
# Delhi                           Placed                  12
# Hydrabad                        Placed                   6
# Indore                          Placed                  14
# Pune                            Placed                   9
# Name: OFF Campus Placement, dtype: int64

# %%
plt.figure(figsize=(11,11))
df.groupby('Job Location of Placed student')['OFF Campus Placement'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='OFF Campus Placement'>

# %%
plt.figure(figsize=(7,7))
df.groupby('Job Location of Placed student')['OFF Campus Placement'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Job Location of Placed student,OFF Campus Placement'>

# %%
df.groupby("gender")["OFF Campus Placement"].value_counts()
# Out:
# gender  OFF Campus Placement
# F       Placed                  25
#         Not Placed               2
# M       Placed                  38
#         Not Placed               1
# Name: OFF Campus Placement, dtype: int64

# %%
df.groupby("specialisation")["OFF Campus Placement"].value_counts()
# Out:
# specialisation             OFF Campus Placement
# Electronic Product Design  Placed                  24
#                            Not Placed               2
# Embedded C                 Placed                  39
#                            Not Placed               1
# Name: OFF Campus Placement, dtype: int64

# %%
fig,axes=plt.subplots(2,2,figsize=(16,10))
sns.countplot(data=df,x='Degree',hue='OFF Campus Placement',ax=axes[0,0])
sns.countplot(data=df,x='gender',hue='OFF Campus Placement',ax=axes[0,1])
sns.countplot(data=df,x='specialisation',hue='OFF Campus Placement',ax=axes[1,0])
sns.countplot(data=df,x='OFF Campus Placement',ax=axes[1,1])
plt.show()

# %%
df.groupby("Degree")["OFF Campus Placement"].value_counts()
# Out:
# Degree                    OFF Campus Placement
# Biomedical Engineer       Placed                  19
# Electronic Engineer       Placed                  39
#                           Not Placed               2
# Instrumentation Engineer  Placed                   5
#                           Not Placed               1
# Name: OFF Campus Placement, dtype: int64

# %%
plt.figure(figsize=(11,11))
df.groupby("Degree")["OFF Campus Placement"].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='OFF Campus Placement'>

# %%
plt.figure(figsize=(7,7))
df.groupby("Degree")["OFF Campus Placement"].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Degree,OFF Campus Placement'>

# %% [markdown]
# # count the student in each city

# %%
df['Job Location of Placed student'].value_counts()
# Out:
# Mumbai      132
# Indore       18
# Delhi        17
# Bhopal       14
# Banglore     13
# Pune         11
# Hydrabad      7
# Name: Job Location of Placed student, dtype: int64

# %%
plt.figure(figsize=[11,11])
df['Job Location of Placed student'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Job Location of Placed student'>

# %%
plt.figure(figsize=[11,11])
df['Job Location of Placed student'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finding correlation of all variable

# %%
df.corr()
# Out:
#                                          Sr. No.  1st year percent  \
# Sr. No.                                 1.000000         -0.078155
# 1st year percent                       -0.078155          1.000000
# 2nd year percent                       -0.085711          0.511472
# 3rd Year percent                       -0.088281          0.538404
# 4th Year Percent                        0.063636          0.261993
# Project marks                           0.022327          0.388478
# Total                                  -0.041275          0.776198
# Salary of ON campus Placement Student   0.065787          0.003612
# Salary of OFF Campus Placement Student  0.351903         -0.022158
#
#                                         2nd year percent  3rd Year percent  \
# Sr. No.                                        -0.085711         -0.088281
# 1st year percent                                0.511472          0.538404
# ...

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Compareing specifiation ,Off-campus placement salary and on campus placement salary and draw scatter plot

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x=df.Total,y=df['Salary of ON campus Placement Student'],hue=df['specialisation'])
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x=df.Total,y=df['Salary of OFF Campus Placement Student'],hue=df['specialisation'])
plt.plot()
# Out:
# []

# %%
sns.pairplot(data=df)

# %% [markdown]
# # Conclusion-:

# %% [markdown]
# 1.Acadmic performance are highly influential for a candidate to get placed from ON-Campus Placement.
#
# 2.Past work experience  influence are only on those students whose Total score below 60 in ON-campus Placement
#
# 3.from above two scatter plot of Off-campus placement and ON-campus placement Academic percentages have no    relation towards salary package
#
# 4.Those student who are not placed from ON-campus Placement are selected from Off-campus placement.
#
# 5.In Total 98% student are placed.and 2% Student remain unplaced from Both campus Placement
#
# 6.There are more number of students get selected from ON- campus placement.
#
# 7.In Off-Campus placement Acadmic performance and work experince does not matter ,its Only depends on Students knowledge .
#
# 8.Students who Placed from ON-campus Placement Get high Salary Package.

# %% [markdown]
# # Result

# %% [markdown]
# 1.After analysis we can say that,31% of student ramain Unplaced in On-campus placement and after off campus placement just 2% of student reamin unplaced.
#
# 2.In ON-campus placement students did not meet required criteria that collage want from them. so thay are not eligible for ON-campus Placement,But in OFF-campus placement such things don't matter that much ,the Only thing is to you have enough knowladge about that field which are you going to apply.
#
# 3.in off-campus placement the total and work experience ,both are unaffected.so the student did not got Placed from ON-campus placement are tried to Off-campus Placement

# %% [markdown]
# # Thank You..!!!
